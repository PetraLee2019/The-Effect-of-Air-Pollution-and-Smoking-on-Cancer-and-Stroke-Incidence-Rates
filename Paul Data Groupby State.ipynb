# %%
import pandas as pd

smoke_df = pd.read_csv("CSV_Smoke_Daily_by_State.csv")

state_df = smoke_df.groupby("LocationDesc").mean()

del state_df['YEAR']

state_df.rename(columns = {"LocationDesc": "State"}, inplace=True)
state_df.rename(columns = {"Data_Value": "LOL"}, inplace=True)
state_df
# Out:
#                         LOL
# LocationDesc
# Alabama               73.34
# Alaska                69.72
# Arizona               66.50
# Arkansas              72.86
# California            62.14
# Colorado              67.20
# Connecticut           66.88
# Delaware              72.08
# District of Columbia  58.52
# Florida               68.12
# Georgia               69.40
# Guam                  71.74
# Hawaii                69.88
# Idaho                 71.98
# Illinois              68.42
# Indiana               74.38
# Iowa                  74.34
# Kansas                72.80
# Kentucky              79.54
# Louisiana             71.98
# Maine                 77.08
# Maryland              69.86
# Massachusetts         70.64
# Michigan              73.50
# Minnesota             69.62
# Mississippi           70.84
# Missouri              76.06
# Montana               71.68
# Nebraska              72.84
# Nevada                69.20
# New Hampshire         75.52
# New Jersey            65.56
# New Mexico            65.14
# New York              66.54
# North Carolina        70.44
# North Dakota          72.98
# Ohio                  75.32
# Oklahoma              73.24
# Oregon                70.48
# Pennsylvania          73.32
# Puerto Rico           70.32
# Rhode Island          70.34
# South Carolina        69.62
# South Dakota          68.84
# Tennessee             76.12
# Texas                 62.00
# Utah                  68.96
# Vermont               74.02
# Virginia              70.82
# Washington            69.06
# West Virginia         83.56
# Wisconsin             69.50
# Wyoming               73.78
