# %%
import pandas as pd

# %%
df11 = pd.read_csv("annual_aqi_by_county_2011.csv")
df12 = pd.read_csv("annual_aqi_by_county_2012.csv")
df13 = pd.read_csv("annual_aqi_by_county_2013.csv")
df14 = pd.read_csv("annual_aqi_by_county_2014.csv")
df15 = pd.read_csv("annual_aqi_by_county_2015.csv")

# %%
frames = [df11, df12, df13, df14, df15]
df = pd.concat(frames).reset_index()
df
# Out:
#       index      State                 County  Year  Days with AQI  Good Days  \
# 0         0    Alabama                Baldwin  2011            282        204
# 1         1    Alabama                   Clay  2011            118         80
# 2         2    Alabama                Colbert  2011            279        214
# 3         3    Alabama                 DeKalb  2011            336        257
# 4         4    Alabama                 Elmore  2011            242        192
# 5         5    Alabama                 Etowah  2011            275        208
# 6         6    Alabama                Houston  2011            283        207
# 7         7    Alabama              Jefferson  2011            365        118
# 8         8    Alabama               Lawrence  2011             95         70
# 9         9    Alabama                Madison  2011            331        222
# 10       10    Alabama                 Mobile  2011            304        215
# ...

# %%
new_df = df.groupby(["County"]).mean()
new_df.head()
# Out:
#                 index         Year  Days with AQI   Good Days  Moderate Days  \
# County
# Abbeville  822.400000  2013.000000     220.600000  205.600000      14.800000
# Ada        225.200000  2013.000000     365.200000  285.000000      72.000000
# Adair      722.000000  2013.000000     365.000000  227.400000     130.800000
# Adams      551.692308  2012.923077     341.192308  271.423077      66.730769
# Adjuntas   806.800000  2013.000000      63.400000   60.600000       2.800000
#
#            Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# County
# Abbeville                             0.200000        0.000000
# Ada                                   6.400000        1.600000
# Adair                                 6.400000        0.400000
# Adams                                 2.807692        0.230769
# Adjuntas                              0.000000        0.000000
#
#            Very Unhealthy Days  Hazardous Days     Max AQI  \
# County
# ...

# %%
new_df.to_csv("final_ap_df.csv")

# %%
# df_lung = pd.read_csv("lung_bycounty.csv")
df_skin = pd.read_csv("skin_bycounty.csv", encoding = 'ISO-8859-1')
# df_blood = pd.read_csv("leukemia_bycounty.csv")

# %%
df = df_skin

# %%
df_skin.head()
# Out:
#                          County   FIPS  \
# 0          US (SEER+NPCR)(1,10)      0
# 1        Beaver County, Utah(7)  49001
# 2      Summit County, Utah(7,8)  49043
# 3    Towns County, Georgia(7,8)  13281
# 4  Pickens County, Georgia(7,8)  13227
#
#   Age-Adjusted Incidence Rate() - cases per 100,000  \
# 0                                               21.3
# 1                                               79.6
# 2                                               76.1
# 3                                               62.1
# 4                                               61.6
#
#    Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                           21.2                           21.3
# 1                           50.9                          118.5
# 2                           63.0                           91.0
# 3                           43.8                           86.3
# 4                           50.8                           74.3
#
# ...

# %%
frames2 = [df_lung, df_skin, df_blood]
df_cancer = pd.concat(frames2).reset_index()
df_cancer = df_cancer[df_cancer.line_race == "Data Suppressed"]
rate = df_cancer["CaseCount"].astype(dtype="float") / df_cancer["Population"].astype(dtype="float") * 100
rate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-6828ee0af933> in <module>
#       1 frames2 = [df_lung, df_skin, df_blood]
#       2 df_cancer = pd.concat(frames2).reset_index()
# ----> 3 df_cancer = df_cancer[df_cancer.line_race == "Data Suppressed"]
#       4 rate = df_cancer["CaseCount"].astype(dtype="float") / df_cancer["Population"].astype(dtype="float") * 100
#       5 rate
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'line_race'

# %%
new_df_cancer = df_cancer.groupby(["Year", "Area", "CancerType"]).mean()
new_df_cancer
# Out:
#                                                  index  AgeAdjustedRate   lci  \
# Year Area                 CancerType
# 1999 Alabama              Leukemias                  3              9.3   8.4
#                           Lung and Bronchus         19             72.8  70.4
#                           Melanomas of the Skin     13             13.5  12.4
#      Alaska               Leukemias                 35             15.4  11.2
#                           Lung and Bronchus         20             79.2  69.4
#                           Melanomas of the Skin      7             11.2   7.9
#      Arizona              Leukemias                  5             10.6   9.7
#                           Lung and Bronchus          4             59.7  57.6
#                           Melanomas of the Skin     30             18.6  17.4
#      Arkansas             Leukemias                 36              NaN   NaN
# ...
