# %%
import pandas as pd

# %%
df11 = pd.read_csv("annual_aqi_by_county_2011.csv")
df12 = pd.read_csv("annual_aqi_by_county_2012.csv")
df13 = pd.read_csv("annual_aqi_by_county_2013.csv")
df14 = pd.read_csv("annual_aqi_by_county_2014.csv")
df15 = pd.read_csv("annual_aqi_by_county_2015.csv")

# %%
frames = [df11, df12, df13, df14, df15]
df_air = pd.concat(frames).reset_index()
df_air.head()
# Out:
#    index    State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0      0  Alabama  Baldwin  2011            282        204             69
# 1      1  Alabama     Clay  2011            118         80             38
# 2      2  Alabama  Colbert  2011            279        214             64
# 3      3  Alabama   DeKalb  2011            336        257             78
# 4      4  Alabama   Elmore  2011            242        192             48
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    9               0                    0
# 1                                    0               0                    0
# 2                                    1               0                    0
# 3                                    1               0                    0
# 4                                    2               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0      126                   74          42        0
# 1               0       86                   63          39        0
# 2               0      101                   61          42        0
# 3               0      101                   63          40        0
# 4               0      105                   64          44        0
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10
# 0         0         209         0          73          0
# 1         0           0         0         118          0
# 2         0         197         0          82          0
# 3         0         271         0          65          0
# 4         0         242         0           0          0

# %%
df_air.County = df_air.County + " County, " + df_air.State
df_air.head()
# Out:
#    index    State                   County  Year  Days with AQI  Good Days  \
# 0      0  Alabama  Baldwin County, Alabama  2011            282        204
# 1      1  Alabama     Clay County, Alabama  2011            118         80
# 2      2  Alabama  Colbert County, Alabama  2011            279        214
# 3      3  Alabama   DeKalb County, Alabama  2011            336        257
# 4      4  Alabama   Elmore County, Alabama  2011            242        192
#
#    Moderate Days  Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# 0             69                                    9               0
# 1             38                                    0               0
# 2             64                                    1               0
# 3             78                                    1               0
# 4             48                                    2               0
#
#    Very Unhealthy Days  Hazardous Days  Max AQI  90th Percentile AQI  \
# 0                    0               0      126                   74
# 1                    0               0       86                   63
# 2                    0               0      101                   61
# 3                    0               0      101                   63
# 4                    0               0      105                   64
#
#    Median AQI  Days CO  Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10
# 0          42        0         0         209         0          73          0
# 1          39        0         0           0         0         118          0
# 2          42        0         0         197         0          82          0
# 3          40        0         0         271         0          65          0
# 4          44        0         0         242         0           0          0

# %%
df_air.to_csv("final_ap_df.csv")

# %%
df_air.drop(columns=["index","State", "Year"], inplace=True)
final_df_air = df_air.groupby("County").mean()
final_df_air.head()
# Out:
#                                   Days with AQI  Good Days  Moderate Days  \
# County
# Abbeville County, South Carolina          220.6      205.6           14.8
# Ada County, Idaho                         365.2      285.0           72.0
# Adair County, Oklahoma                    365.0      227.4          130.8
# Adams County, Colorado                    365.0      231.6          124.6
# Adams County, Illinois                    291.8      265.2           25.6
#
#                                   Unhealthy for Sensitive Groups Days  \
# County
# Abbeville County, South Carolina                                  0.2
# Ada County, Idaho                                                 6.4
# Adair County, Oklahoma                                            6.4
# Adams County, Colorado                                            8.4
# Adams County, Illinois                                            0.8
#
#                                   Unhealthy Days  Very Unhealthy Days  \
# County
# Abbeville County, South Carolina             0.0                  0.0
# Ada County, Idaho                            1.6                  0.2
# Adair County, Oklahoma                       0.4                  0.0
# Adams County, Colorado                       0.4                  0.0
# Adams County, Illinois                       0.2                  0.0
#
#                                   Hazardous Days  Max AQI  \
# County
# Abbeville County, South Carolina             0.0     92.4
# Ada County, Idaho                            0.0    166.2
# Adair County, Oklahoma                       0.0    137.6
# Adams County, Colorado                       0.0    138.4
# Adams County, Illinois                       0.0    106.2
#
#                                   90th Percentile AQI  Median AQI  Days CO  \
# County
# Abbeville County, South Carolina                 48.6        36.2      0.0
# Ada County, Idaho                                65.0        39.4      4.8
# Adair County, Oklahoma                           71.2        45.6      0.0
# Adams County, Colorado                           75.6        47.0      0.0
# Adams County, Illinois                           50.2        37.2      0.0
#
#                                   Days NO2  Days Ozone  Days SO2  Days PM2.5  \
# County
# Abbeville County, South Carolina       0.0       220.6       0.0         0.0
# Ada County, Idaho                     47.0       223.6       0.2        47.0
# Adair County, Oklahoma                 1.6       212.6       1.0       147.0
# Adams County, Colorado               108.8       204.8       1.0        21.8
# Adams County, Illinois                 0.0       291.8       0.0         0.0
#
#                                   Days PM10
# County
# Abbeville County, South Carolina        0.0
# Ada County, Idaho                      42.6
# Adair County, Oklahoma                  2.8
# Adams County, Colorado                 28.6
# Adams County, Illinois                  0.0

# %%
df_lung = pd.read_csv("lung_bycounty.csv", encoding = 'ISO-8859-1')
df_skin = pd.read_csv("skin_bycounty.csv", encoding = 'ISO-8859-1')
df_blood = pd.read_csv("leukemia_bycounty.csv", encoding = 'ISO-8859-1')

# %%
df_blood.head()
# Out:
#                                  County     FIPS  \
# 0                  US (SEER+NPCR)(1,10)      0.0
# 1     Turner County, South Dakota(6,10)  46125.0
# 2  Mountrail County, North Dakota(6,10)  38061.0
# 3  Bon Homme County, South Dakota(6,10)  46009.0
# 4          Iron County, Wisconsin(6,10)  55051.0
#
#   Met Healthy People Objective of ***?  \
# 0                                  ***
# 1                                  ***
# 2                                  ***
# 3                                  ***
# 4                                  ***
#
#   Age-Adjusted Incidence Rate() - cases per 100,000  \
# 0                                               13.6
# 1                                               41.9
# 2                                               35.7
# 3                                               32.6
# 4                                               30.2
#
#   Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                          13.6                          13.7
# 1                          25.2                          65.9
# 2                            20                          58.7
# 3                          17.8                          55.6
# 4                          15.6                            56
#
#   Average Annual Count Recent Trend  \
# 0                47270      falling
# 1                    4       stable
# 2                    3            *
# 3                    3            *
# 4                    3            *
#
#   Recent 5-Year Trend () in Incidence Rates Lower 95% Confidence Interval.1  \
# 0                                       -1.6                            -2.7
# 1                                       -5.5                           -43.8
# 2                                          *                               *
# 3                                          *                               *
# 4                                          *                               *
#
#   Upper 95% Confidence Interval.1
# 0                            -0.5
# 1                            58.8
# 2                               *
# 3                               *
# 4                               *

# %%
df_skin.columns = ["County", "a", "Incidence Rate", "b", "c", "d", "e", "f", "g", "h"]
df_lung.columns = ["County", "a", "a2", "Incidence Rate", "b", "c", "d", "e", "f", "g", "h"]
df_blood.columns = ["County", "a", "a2", "Incidence Rate", "b", "c", "d", "e", "f", "g", "h"]

df_skin.drop(columns=["a","b", "c", "d", "e", "f", "g", "h"], inplace=True)
df_lung.drop(columns=["a", "a2", "b", "c", "d", "e", "f", "g", "h"], inplace=True)
df_blood.drop(columns=["a", "a2", "b", "c", "d", "e", "f", "g", "h"], inplace=True)

# %%
df_skin["Incidence Rate"] = df_skin["Incidence Rate"].str.replace("#", "")
df_lung["Incidence Rate"] = df_lung["Incidence Rate"].str.replace("#", "")
df_blood["Incidence Rate"] = df_blood["Incidence Rate"].str.replace("#", "")
df_blood.head()
# Out:
#                                  County Incidence Rate
# 0                  US (SEER+NPCR)(1,10)           13.6
# 1     Turner County, South Dakota(6,10)           41.9
# 2  Mountrail County, North Dakota(6,10)           35.7
# 3  Bon Homme County, South Dakota(6,10)           32.6
# 4          Iron County, Wisconsin(6,10)           30.2

# %%
df_skin.drop(0, inplace=True)
df_lung.drop(0, inplace=True)
df_blood.drop(0, inplace=True)
df_skin.head()
# Out:
#                          County Incidence Rate
# 1        Beaver County, Utah(7)           79.6
# 2      Summit County, Utah(7,8)           76.1
# 3    Towns County, Georgia(7,8)           62.1
# 4  Pickens County, Georgia(7,8)           61.6
# 5  Lumpkin County, Georgia(7,8)           56.8

# %%
new_skin = df_skin["County"].str.split("(", n = 1, expand = True)
df_skin["County"]= new_skin[0]
df_skin.head()
# Out:
#                     County Incidence Rate
# 1      Beaver County, Utah           79.6
# 2      Summit County, Utah           76.1
# 3    Towns County, Georgia           62.1
# 4  Pickens County, Georgia           61.6
# 5  Lumpkin County, Georgia           56.8

# %%
new_blood = df_blood["County"].str.split("(", n = 1, expand = True)
df_blood["County"]= new_blood[0]
df_blood.head()
# Out:
#                            County Incidence Rate
# 1     Turner County, South Dakota           41.9
# 2  Mountrail County, North Dakota           35.7
# 3  Bon Homme County, South Dakota           32.6
# 4          Iron County, Wisconsin           30.2
# 5     Washington County, Kentucky           29.4

# %%
new_lung = df_lung["County"].str.split("(", n = 1, expand = True)
df_lung["County"]= new_lung[0]
df_lung.head()
# Out:
#                         County Incidence Rate
# 1        Union County, Florida          215.1
# 2      Owsley County, Kentucky          179.7
# 3    McCreary County, Kentucky          154.1
# 4  North Slope Borough, Alaska          150.8
# 5      Powell County, Kentucky          140.9

# %%
df_blood_mod = df_blood
df_blood_mod["Ilness Type"] = "Blood cancer"
df_blood_mod.head()
# Out:
#                            County Incidence Rate   Ilness Type
# 1     Turner County, South Dakota           41.9  Blood cancer
# 2  Mountrail County, North Dakota           35.7  Blood cancer
# 3  Bon Homme County, South Dakota           32.6  Blood cancer
# 4          Iron County, Wisconsin           30.2  Blood cancer
# 5     Washington County, Kentucky           29.4  Blood cancer

# %%
df_lung_mod = df_lung
df_lung_mod["Ilness Type"] = "Lung cancer"
df_lung_mod.head()
# Out:
#                         County Incidence Rate  Ilness Type
# 1        Union County, Florida          215.1  Lung cancer
# 2      Owsley County, Kentucky          179.7  Lung cancer
# 3    McCreary County, Kentucky          154.1  Lung cancer
# 4  North Slope Borough, Alaska          150.8  Lung cancer
# 5      Powell County, Kentucky          140.9  Lung cancer

# %%
df_skin_mod = df_skin
df_skin_mod["Ilness Type"] = "Skin cancer"
df_skin_mod.head()
# Out:
#                     County Incidence Rate  Ilness Type
# 1      Beaver County, Utah           79.6  Skin cancer
# 2      Summit County, Utah           76.1  Skin cancer
# 3    Towns County, Georgia           62.1  Skin cancer
# 4  Pickens County, Georgia           61.6  Skin cancer
# 5  Lumpkin County, Georgia           56.8  Skin cancer

# %%
print("lung:")
print(df_lung_mod.count())
print("blood:")
print(df_blood_mod.count())
print("skin:")
print(df_skin_mod.count())
# Out:
# lung:
# County            2709
# Incidence Rate    2709
# Ilness Type       2709
# dtype: int64
# blood:
# County            3161
# Incidence Rate    3141
# Ilness Type       3169
# dtype: int64
# skin:
# County            2075
# Incidence Rate    2075
# Ilness Type       2075
# dtype: int64

# %%
frames_cancer = [df_lung_mod, df_blood_mod, df_skin_mod]
cancer_df = pd.concat(frames_cancer).reset_index()
cancer_df.count()
# Out:
# index             7953
# County            7945
# Incidence Rate    7925
# Ilness Type       7953
# dtype: int64

# %%
cancer_df.head()
# Out:
#    index                       County Incidence Rate  Ilness Type
# 0      1        Union County, Florida          215.1  Lung cancer
# 1      2      Owsley County, Kentucky          179.7  Lung cancer
# 2      3    McCreary County, Kentucky          154.1  Lung cancer
# 3      4  North Slope Borough, Alaska          150.8  Lung cancer
# 4      5      Powell County, Kentucky          140.9  Lung cancer

# %%
cancer_df["Incidence Rate"] = cancer_df["Incidence Rate"].str.replace("*", "")
cancer_df.reset_index()
cancer_df.set_index("index", inplace = True)
cancer_df.head()
# Out:
#                             County Incidence Rate  Ilness Type
# index
# 1            Union County, Florida          215.1  Lung cancer
# 2          Owsley County, Kentucky          179.7  Lung cancer
# 3        McCreary County, Kentucky          154.1  Lung cancer
# 4      North Slope Borough, Alaska          150.8  Lung cancer
# 5          Powell County, Kentucky          140.9  Lung cancer

# %%
aqi_illness_df = pd.DataFrame(pd.merge(final_df_air, cancer_df, how = "outer", on='County'))
aqi_illness_df.head()
# Out:
#                              County  Days with AQI  Good Days  Moderate Days  \
# 0  Abbeville County, South Carolina          220.6      205.6           14.8
# 1  Abbeville County, South Carolina          220.6      205.6           14.8
# 2  Abbeville County, South Carolina          220.6      205.6           14.8
# 3                 Ada County, Idaho          365.2      285.0           72.0
# 4                 Ada County, Idaho          365.2      285.0           72.0
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                  0.2             0.0                  0.0
# 1                                  0.2             0.0                  0.0
# 2                                  0.2             0.0                  0.0
# 3                                  6.4             1.6                  0.2
# 4                                  6.4             1.6                  0.2
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0             0.0     92.4                 48.6        36.2      0.0
# 1             0.0     92.4                 48.6        36.2      0.0
# 2             0.0     92.4                 48.6        36.2      0.0
# 3             0.0    166.2                 65.0        39.4      4.8
# 4             0.0    166.2                 65.0        39.4      4.8
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Incidence Rate  \
# 0       0.0       220.6       0.0         0.0        0.0           69.2
# 1       0.0       220.6       0.0         0.0        0.0           11.9
# 2       0.0       220.6       0.0         0.0        0.0           18.2
# 3      47.0       223.6       0.2        47.0       42.6           52.3
# 4      47.0       223.6       0.2        47.0       42.6             16
#
#     Ilness Type
# 0   Lung cancer
# 1  Blood cancer
# 2   Skin cancer
# 3   Lung cancer
# 4  Blood cancer

# %%
aqi_illness_df.loc[1000:1010,:]
# Out:
#                          County  Days with AQI  Good Days  Moderate Days  \
# 1000  Fresno County, California          365.2       66.4          174.4
# 1001  Fresno County, California          365.2       66.4          174.4
# 1002  Fresno County, California          365.2       66.4          174.4
# 1003     Fulton County, Georgia          365.0      216.6          136.0
# 1004     Fulton County, Georgia          365.0      216.6          136.0
# 1005     Fulton County, Georgia          365.0      216.6          136.0
# 1006   Gallatin County, Montana          365.2      312.6           50.0
# 1007   Gallatin County, Montana          365.2      312.6           50.0
# 1008   Gallatin County, Montana          365.2      312.6           50.0
# 1009    Galveston County, Texas          365.2      283.0           73.6
# 1010    Galveston County, Texas          365.2      283.0           73.6
#
#       Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# 1000                                 91.6            32.4
# 1001                                 91.6            32.4
# 1002                                 91.6            32.4
# 1003                                 10.4             2.0
# 1004                                 10.4             2.0
# 1005                                 10.4             2.0
# 1006                                  2.4             0.2
# 1007                                  2.4             0.2
# 1008                                  2.4             0.2
# 1009                                  7.6             0.8
# 1010                                  7.6             0.8
#
#       Very Unhealthy Days  Hazardous Days  Max AQI  90th Percentile AQI  \
# 1000                  0.4             0.0    201.6                146.8
# 1001                  0.4             0.0    201.6                146.8
# 1002                  0.4             0.0    201.6                146.8
# 1003                  0.0             0.0    169.6                 73.2
# 1004                  0.0             0.0    169.6                 73.2
# 1005                  0.0             0.0    169.6                 73.2
# 1006                  0.0             0.0    115.2                 54.4
# 1007                  0.0             0.0    115.2                 54.4
# 1008                  0.0             0.0    115.2                 54.4
# 1009                  0.2             0.0    155.6                 65.8
# 1010                  0.2             0.0    155.6                 65.8
#
#       Median AQI  Days CO  Days NO2  Days Ozone  Days SO2  Days PM2.5  \
# 1000        81.6      0.0       0.4       217.4       0.0       144.6
# 1001        81.6      0.0       0.4       217.4       0.0       144.6
# 1002        81.6      0.0       0.4       217.4       0.0       144.6
# 1003        46.6      0.6       9.0       125.8       2.4       226.8
# 1004        46.6      0.6       9.0       125.8       2.4       226.8
# 1005        46.6      0.6       9.0       125.8       2.4       226.8
# 1006        26.2      2.2      15.0         0.0       0.0       348.0
# 1007        26.2      2.2      15.0         0.0       0.0       348.0
# 1008        26.2      2.2      15.0         0.0       0.0       348.0
# 1009        39.6      0.0       2.4       233.4       2.8       124.8
# 1010        39.6      0.0       2.4       233.4       2.8       124.8
#
#       Days PM10 Incidence Rate   Ilness Type
# 1000        2.8           46.9   Lung cancer
# 1001        2.8           12.2  Blood cancer
# 1002        2.8           16.8   Skin cancer
# 1003        0.4           51.2   Lung cancer
# 1004        0.4           13.6  Blood cancer
# 1005        0.4           28.9   Skin cancer
# 1006        0.0           33.1   Lung cancer
# 1007        0.0           14.6  Blood cancer
# 1008        0.0           34.6   Skin cancer
# 1009        1.8           59.2   Lung cancer
# 1010        1.8           13.8  Blood cancer

# %%
aqi_illness_df.loc[aqi_illness_df["Ilness Type"] == "nan"]
# Out:
# Empty DataFrame
# Columns: [County, Days with AQI, Good Days, Moderate Days, Unhealthy for Sensitive Groups Days, Unhealthy Days, Very Unhealthy Days, Hazardous Days, Max AQI, 90th Percentile AQI, Median AQI, Days CO, Days NO2, Days Ozone, Days SO2, Days PM2.5, Days PM10, Incidence Rate, Ilness Type]
# Index: []

# %%
aqi_illness_df.dropna(how="all")
aqi_illness_df.count()
# Out:
# County                                 8017
# Days with AQI                          3036
# Good Days                              3036
# Moderate Days                          3036
# Unhealthy for Sensitive Groups Days    3036
# Unhealthy Days                         3036
# Very Unhealthy Days                    3036
# Hazardous Days                         3036
# Max AQI                                3036
# 90th Percentile AQI                    3036
# Median AQI                             3036
# Days CO                                3036
# Days NO2                               3036
# Days Ozone                             3036
# Days SO2                               3036
# Days PM2.5                             3036
# Days PM10                              3036
# Incidence Rate                         7925
# Ilness Type                            7953
# dtype: int64

# %%
df_skin.rename(columns={"Incidence Rate": "Skin_IR"}, inplace=True)
df_skin.head()
# Out:
#                     County Skin_IR
# 1      Beaver County, Utah    79.6
# 2      Summit County, Utah    76.1
# 3    Towns County, Georgia    62.1
# 4  Pickens County, Georgia    61.6
# 5  Lumpkin County, Georgia    56.8

# %%
df_blood.rename(columns={"Incidence Rate": "Blood_IR"}, inplace=True)
df_lung.rename(columns={"Incidence Rate": "Lung_IR"}, inplace=True)

# %%
skin_lung_df = pd.merge(df_skin, df_lung, on='County')
skin_lung_df.head()
# Out:
#                     County Skin_IR Lung_IR
# 0      Summit County, Utah    76.1    18.6
# 1    Towns County, Georgia    62.1    65.9
# 2  Pickens County, Georgia    61.6    81.5
# 3  Lumpkin County, Georgia    56.8    73.6
# 4  Forsyth County, Georgia    55.2    54.6

# %%
final_cancer_df = pd.merge(skin_lung_df, df_blood, on='County')
final_cancer_df.head()
# Out:
#                     County Skin_IR Lung_IR Blood_IR
# 0      Summit County, Utah    76.1    18.6     11.2
# 1    Towns County, Georgia    62.1    65.9       *
# 2  Pickens County, Georgia    61.6    81.5     16.4
# 3  Lumpkin County, Georgia    56.8    73.6     15.5
# 4  Forsyth County, Georgia    55.2    54.6     16.9

# %%
final_cancer_df.Skin_IR = final_cancer_df.Skin_IR.str.replace("*", "")
final_cancer_df.Lung_IR = final_cancer_df.Lung_IR.str.replace("*", "")
final_cancer_df.Blood_IR = final_cancer_df.Blood_IR.str.replace("*", "")
final_cancer_df.head()
# Out:
#                     County Skin_IR Lung_IR Blood_IR
# 0      Summit County, Utah    76.1    18.6     11.2
# 1    Towns County, Georgia    62.1    65.9
# 2  Pickens County, Georgia    61.6    81.5     16.4
# 3  Lumpkin County, Georgia    56.8    73.6     15.5
# 4  Forsyth County, Georgia    55.2    54.6     16.9

# %%
final_df = pd.merge(final_df_air, final_cancer_df, on='County')
final_df.head()
# Out:
#                              County  Days with AQI  Good Days  Moderate Days  \
# 0  Abbeville County, South Carolina          220.6      205.6           14.8
# 1                 Ada County, Idaho          365.2      285.0           72.0
# 2            Adams County, Colorado          365.0      231.6          124.6
# 3            Adams County, Illinois          291.8      265.2           25.6
# 4         Adams County, Mississippi          174.0      139.0           34.0
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                  0.2             0.0                  0.0
# 1                                  6.4             1.6                  0.2
# 2                                  8.4             0.4                  0.0
# 3                                  0.8             0.2                  0.0
# 4                                  1.0             0.0                  0.0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0             0.0     92.4                 48.6        36.2      0.0
# 1             0.0    166.2                 65.0        39.4      4.8
# 2             0.0    138.4                 75.6        47.0      0.0
# 3             0.0    106.2                 50.2        37.2      0.0
# 4             0.0    101.0                 67.0        41.0      0.0
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Skin_IR Lung_IR  \
# 0       0.0       220.6       0.0         0.0        0.0    18.2    69.2
# 1      47.0       223.6       0.2        47.0       42.6      33    52.3
# 2     108.8       204.8       1.0        21.8       28.6    15.3    52.9
# 3       0.0       291.8       0.0         0.0        0.0    31.9    73.1
# 4       0.0       174.0       0.0         0.0        0.0      13    65.5
#
#   Blood_IR
# 0     11.9
# 1       16
# 2       12
# 3     11.1
# 4     12.5

# %%
len(final_df)
# Out:
# 923

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(final_df["Median AQI"].astype("float"), final_df["Lung_IR"].astype("float"), "bo")
plt.title("Median AQI vs Lung Cancer Incidence Rate")
plt.xlabel("Median AQI")
plt.ylabel("Incidence Rate")
plt.show()

# %%
plt.plot(final_df["Median AQI"].astype("float"), final_df["Skin_IR"].astype("float"), "bo")
plt.title("Median AQI vs Skin Cancer Incidence Rate")
plt.xlabel("Median AQI")
plt.ylabel("Incidence Rate")
plt.show()

# %%
plt.plot(final_df["Days Ozone"].astype("float"), final_df["Lung_IR"].astype("float"), "bo")
plt.title("Days Ozone vs Leukemia Incidence Rate")
plt.xlabel("Days Ozone")
plt.ylabel("Incidence Rate")
plt.show()

# %%
cancer_types = list(aqi_illness_df["Ilness Type"].unique())
cancer_types
# Out:
# ['Lung cancer', 'Blood cancer', 'Skin cancer', nan]

# %%
AQI = aqi_illness_df.groupby(["County"])

# %%
# Build a Bubble Plot that showcases the relationship between four key variables:
# Incident Rate - y_axis
# Media AQI - x_axis
# Days with AQI - size
# Cancer Type ['Lung cancer', 'Blood cancer', 'Skin cancer', nan] - color(legend)

# Cancer Type 
ilness_types = list(aqi_illness_df["Ilness Type"].unique())
# ['Lung cancer', 'Blood cancer', 'Skin cancer', nan]

# Define colors 
colors = ["Coral","Skyblue","Gold","Green"]

# Define color scheme
color_schema_df = pd.DataFrame(zip(ilness_types,colors),columns=["Ilness Type","color"])
# Set "type" as index
color_schema_df.set_index("Ilness Type",drop=True,inplace=True)

# Obtain the x and y coordinates for each of the three city types
# Group merged data by city type and city -> 
AQI_illness_county = aqi_illness_df.groupby(["County", "Ilness Type"])

# Average Fare ($) Per City -> y_value
illnes_rate = aqi_illness_df["Incidence Rate"].mean()

# Total Number of Rides Per City -> x_value
total_rides_city = pyber_city["ride_id"].count()

# Total Number of Drivers Per City -> bubble's size
total_drivers_city = pyber_city["driver_count"].max()

# Create subplot
fig,ax = plt.subplots() 
fig.suptitle("Piber Ride Sharing Data (2016)", y=0.95, fontsize=12, fontweight='bold')

# Build the scatter plots for each city types
for x in color_schema_df.index:
    x_axis = total_rides_city[x]
    y_axis = avr_fare_city[x]
    c=color_schema_df.loc[x]["color"] 
    size = [s*10 for s in total_drivers_city[x]]   
    plt.scatter(x_axis, y_axis, marker="o", facecolor=c, edgecolor="black",alpha=0.75, s=size, label=x, linewidths=1)

# Incorporate the other graph properties
x_max = total_rides_city.max()
y_max = avr_fare_city.max()
x_min = total_rides_city.min()
y_min = avr_fare_city.min()
plt.xlim(0, x_max+2)
plt.ylim(y_min-1.3, y_max+1)
# plt.title("Piber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.grid()

# Place a legend on the chart in what matplotlib believes to be the "best" location
plt.legend(title="City types", loc="best", fontsize="small", shadow=True, markerscale=0.6) 

# Incorporate a text label regarding circle size
plt_note = "Note: \nCircle size correlates with driver count per city"
ax.text(1.05, 0.65, plt_note,
        verticalalignment='center', horizontalalignment='left',
        transform=ax.transAxes,
        color='black', fontsize=10)

# Show plot
plt.show()
