# %%
# !!!!!!! Olga !!!!!!!
# Out:
# ['/bin/bash: !!!!!: command not found']

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !!!!!!! Olga !!!!!!!
# Out:
# ['/bin/bash: !!!!!: command not found']

# %%
df11 = pd.read_csv("annual_aqi_by_county_2011.csv")
df12 = pd.read_csv("annual_aqi_by_county_2012.csv")
df13 = pd.read_csv("annual_aqi_by_county_2013.csv")
df14 = pd.read_csv("annual_aqi_by_county_2014.csv")
df15 = pd.read_csv("annual_aqi_by_county_2015.csv")

# %%
frames = [df11, df12, df13, df14, df15]
df_air = pd.concat(frames).reset_index()
df_air.head()
# Out:
#    index    State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0      0  Alabama  Baldwin  2011            282        204             69
# 1      1  Alabama     Clay  2011            118         80             38
# 2      2  Alabama  Colbert  2011            279        214             64
# 3      3  Alabama   DeKalb  2011            336        257             78
# 4      4  Alabama   Elmore  2011            242        192             48
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    9               0                    0
# 1                                    0               0                    0
# 2                                    1               0                    0
# 3                                    1               0                    0
# 4                                    2               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0      126                   74          42        0
# 1               0       86                   63          39        0
# 2               0      101                   61          42        0
# 3               0      101                   63          40        0
# 4               0      105                   64          44        0
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10
# 0         0         209         0          73          0
# 1         0           0         0         118          0
# 2         0         197         0          82          0
# 3         0         271         0          65          0
# 4         0         242         0           0          0

# %%
df_air.County = df_air.County + " County, " + df_air.State
df_air.head()
# Out:
#    index    State                   County  Year  Days with AQI  Good Days  \
# 0      0  Alabama  Baldwin County, Alabama  2011            282        204
# 1      1  Alabama     Clay County, Alabama  2011            118         80
# 2      2  Alabama  Colbert County, Alabama  2011            279        214
# 3      3  Alabama   DeKalb County, Alabama  2011            336        257
# 4      4  Alabama   Elmore County, Alabama  2011            242        192
#
#    Moderate Days  Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# 0             69                                    9               0
# 1             38                                    0               0
# 2             64                                    1               0
# 3             78                                    1               0
# 4             48                                    2               0
#
#    Very Unhealthy Days  Hazardous Days  Max AQI  90th Percentile AQI  \
# 0                    0               0      126                   74
# 1                    0               0       86                   63
# 2                    0               0      101                   61
# 3                    0               0      101                   63
# 4                    0               0      105                   64
#
#    Median AQI  Days CO  Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10
# 0          42        0         0         209         0          73          0
# 1          39        0         0           0         0         118          0
# 2          42        0         0         197         0          82          0
# 3          40        0         0         271         0          65          0
# 4          44        0         0         242         0           0          0

# %%
df_air.to_csv("final_ap_df.csv")

# %%
df_air.drop(columns=["index","State", "Year"], inplace=True)
final_df_air = df_air.groupby("County").mean()
final_df_air.head()
# Out:
#                                   Days with AQI  Good Days  Moderate Days  \
# County
# Abbeville County, South Carolina          220.6      205.6           14.8
# Ada County, Idaho                         365.2      285.0           72.0
# Adair County, Oklahoma                    365.0      227.4          130.8
# Adams County, Colorado                    365.0      231.6          124.6
# Adams County, Illinois                    291.8      265.2           25.6
#
#                                   Unhealthy for Sensitive Groups Days  \
# County
# Abbeville County, South Carolina                                  0.2
# Ada County, Idaho                                                 6.4
# Adair County, Oklahoma                                            6.4
# Adams County, Colorado                                            8.4
# Adams County, Illinois                                            0.8
#
#                                   Unhealthy Days  Very Unhealthy Days  \
# County
# Abbeville County, South Carolina             0.0                  0.0
# Ada County, Idaho                            1.6                  0.2
# Adair County, Oklahoma                       0.4                  0.0
# Adams County, Colorado                       0.4                  0.0
# Adams County, Illinois                       0.2                  0.0
#
#                                   Hazardous Days  Max AQI  \
# County
# Abbeville County, South Carolina             0.0     92.4
# Ada County, Idaho                            0.0    166.2
# Adair County, Oklahoma                       0.0    137.6
# Adams County, Colorado                       0.0    138.4
# Adams County, Illinois                       0.0    106.2
#
#                                   90th Percentile AQI  Median AQI  Days CO  \
# County
# Abbeville County, South Carolina                 48.6        36.2      0.0
# Ada County, Idaho                                65.0        39.4      4.8
# Adair County, Oklahoma                           71.2        45.6      0.0
# Adams County, Colorado                           75.6        47.0      0.0
# Adams County, Illinois                           50.2        37.2      0.0
#
#                                   Days NO2  Days Ozone  Days SO2  Days PM2.5  \
# County
# Abbeville County, South Carolina       0.0       220.6       0.0         0.0
# Ada County, Idaho                     47.0       223.6       0.2        47.0
# Adair County, Oklahoma                 1.6       212.6       1.0       147.0
# Adams County, Colorado               108.8       204.8       1.0        21.8
# Adams County, Illinois                 0.0       291.8       0.0         0.0
#
#                                   Days PM10
# County
# Abbeville County, South Carolina        0.0
# Ada County, Idaho                      42.6
# Adair County, Oklahoma                  2.8
# Adams County, Colorado                 28.6
# Adams County, Illinois                  0.0

# %%
# !!!!!!! Olga !!!!!!!
# Out:
# ['/bin/bash: !!!!!: command not found']

# %%
df_lung = pd.read_csv("lung_bycounty.csv", encoding = 'ISO-8859-1')
df_skin = pd.read_csv("skin_bycounty.csv", encoding = 'ISO-8859-1')
df_blood = pd.read_csv("leukemia_bycounty.csv", encoding = 'ISO-8859-1')
df_stroke = pd.read_csv("Stroke Data Merge.csv", encoding = 'ISO-8859-1')

# %%
df_stroke.head()
# Out:
#                              County  Stroke_IR
# 0  Abbeville County, South Carolina       87.3
# 1   Acadia Parish County, Louisiana       88.9
# 2         Accomack County, Virginia       75.2
# 3                 Ada County, Idaho       66.8
# 4                Adair County, Iowa       62.0

# %%
# !!!!!!! Olga !!!!!!!
# Out:
# ['/bin/bash: !!!!!: command not found']

# %%
df_blood.head()
# Out:
#                                  County     FIPS  \
# 0                  US (SEER+NPCR)(1,10)      0.0
# 1     Turner County, South Dakota(6,10)  46125.0
# 2  Mountrail County, North Dakota(6,10)  38061.0
# 3  Bon Homme County, South Dakota(6,10)  46009.0
# 4          Iron County, Wisconsin(6,10)  55051.0
#
#   Met Healthy People Objective of ***?  \
# 0                                  ***
# 1                                  ***
# 2                                  ***
# 3                                  ***
# 4                                  ***
#
#   Age-Adjusted Incidence Rate() - cases per 100,000  \
# 0                                               13.6
# 1                                               41.9
# 2                                               35.7
# 3                                               32.6
# 4                                               30.2
#
#   Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                          13.6                          13.7
# 1                          25.2                          65.9
# 2                            20                          58.7
# 3                          17.8                          55.6
# 4                          15.6                            56
#
#   Average Annual Count Recent Trend  \
# 0                47270      falling
# 1                    4       stable
# 2                    3            *
# 3                    3            *
# 4                    3            *
#
#   Recent 5-Year Trend () in Incidence Rates Lower 95% Confidence Interval.1  \
# 0                                       -1.6                            -2.7
# 1                                       -5.5                           -43.8
# 2                                          *                               *
# 3                                          *                               *
# 4                                          *                               *
#
#   Upper 95% Confidence Interval.1
# 0                            -0.5
# 1                            58.8
# 2                               *
# 3                               *
# 4                               *

# %%
# !!!!!!! Olga !!!!!!!
# Out:
# ['/bin/bash: !!!!!: command not found']

# %%
df_skin.columns = ["County", "a", "Ilness_Rate", "b", "c", "d", "e", "f", "g", "h"]
df_lung.columns = ["County", "a", "a2", "Ilness_Rate", "b", "c", "d", "e", "f", "g", "h"]
df_blood.columns = ["County", "a", "a2", "Ilness_Rate", "b", "c", "d", "e", "f", "g", "h"]
df_stroke.columns = ["County","Ilness_Rate"]

df_skin.drop(columns=["a","b", "c", "d", "e", "f", "g", "h"], inplace=True)
df_lung.drop(columns=["a", "a2", "b", "c", "d", "e", "f", "g", "h"], inplace=True)
df_blood.drop(columns=["a", "a2", "b", "c", "d", "e", "f", "g", "h"], inplace=True)

# %%
# !!!!!!! Olga !!!!!!!
# Out:
# ['/bin/bash: !!!!!: command not found']

# %%
df_skin.drop(0, inplace=True)
df_lung.drop(0, inplace=True)
df_blood.drop(0, inplace=True)
df_skin.head()
# Out:
#                          County Ilness_Rate
# 1        Beaver County, Utah(7)        79.6
# 2      Summit County, Utah(7,8)        76.1
# 3    Towns County, Georgia(7,8)        62.1
# 4  Pickens County, Georgia(7,8)        61.6
# 5  Lumpkin County, Georgia(7,8)        56.8

# %%
new_skin = df_skin["County"].str.split("(", n = 1, expand = True)
df_skin["County"]= new_skin[0]
df_skin.head()
# Out:
#                     County Ilness_Rate
# 1      Beaver County, Utah        79.6
# 2      Summit County, Utah        76.1
# 3    Towns County, Georgia        62.1
# 4  Pickens County, Georgia        61.6
# 5  Lumpkin County, Georgia        56.8

# %%
new_blood = df_blood["County"].str.split("(", n = 1, expand = True)
df_blood["County"]= new_blood[0]
df_blood.head()
# Out:
#                            County Ilness_Rate
# 1     Turner County, South Dakota        41.9
# 2  Mountrail County, North Dakota        35.7
# 3  Bon Homme County, South Dakota        32.6
# 4          Iron County, Wisconsin        30.2
# 5     Washington County, Kentucky        29.4

# %%
new_lung = df_lung["County"].str.split("(", n = 1, expand = True)
df_lung["County"]= new_lung[0]
df_lung.head()
# Out:
#                         County Ilness_Rate
# 1        Union County, Florida       215.1
# 2      Owsley County, Kentucky       179.7
# 3    McCreary County, Kentucky       154.1
# 4  North Slope Borough, Alaska       150.8
# 5      Powell County, Kentucky       140.9

# %%
df_skin.rename(columns={"Incidence Rate": "Skin_IR"}, inplace=True)
df_skin.head()
# Out:
#                     County Ilness_Rate
# 1      Beaver County, Utah        79.6
# 2      Summit County, Utah        76.1
# 3    Towns County, Georgia        62.1
# 4  Pickens County, Georgia        61.6
# 5  Lumpkin County, Georgia        56.8

# %%
df_blood.rename(columns={"Incidence Rate": "Blood_IR"}, inplace=True)
df_lung.rename(columns={"Incidence Rate": "Lung_IR"}, inplace=True)

# %%
skin_lung_df = pd.merge(df_skin, df_lung, on='County')
skin_lung_df.head()
# Out:
#                     County Ilness_Rate_x Ilness_Rate_y
# 0      Summit County, Utah          76.1          18.6
# 1    Towns County, Georgia          62.1          65.9
# 2  Pickens County, Georgia          61.6          81.5
# 3  Lumpkin County, Georgia          56.8          73.6
# 4  Forsyth County, Georgia          55.2          54.6

# %%
final_cancer_df = pd.merge(skin_lung_df, df_blood, on='County')
final_cancer_df.head()
# Out:
#                     County Ilness_Rate_x Ilness_Rate_y Ilness_Rate
# 0      Summit County, Utah          76.1          18.6        11.2
# 1    Towns County, Georgia          62.1          65.9          *
# 2  Pickens County, Georgia          61.6          81.5        16.4
# 3  Lumpkin County, Georgia          56.8          73.6        15.5
# 4  Forsyth County, Georgia          55.2          54.6        16.9

# %%
final_cancer_df.Skin_IR = final_cancer_df.Skin_IR.str.replace("*", "")
final_cancer_df.Lung_IR = final_cancer_df.Lung_IR.str.replace("*", "")
final_cancer_df.Blood_IR = final_cancer_df.Blood_IR.str.replace("*", "")
final_cancer_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-282-5fe400bf837b> in <module>
# ----> 1 final_cancer_df.Skin_IR = final_cancer_df.Skin_IR.str.replace("*", "")
#       2 final_cancer_df.Lung_IR = final_cancer_df.Lung_IR.str.replace("*", "")
#       3 final_cancer_df.Blood_IR = final_cancer_df.Blood_IR.str.replace("*", "")
#       4 final_cancer_df.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Skin_IR'

# %%
final_df = pd.merge(final_df_air, final_cancer_df, on='County')
final_df.head()

# %%
len(final_df)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(final_df["Median AQI"].astype("float"), final_df["Lung_IR"].astype("float"), "bo")
plt.title("Median AQI vs Lung Cancer Incidence Rate")
plt.xlabel("Median AQI")
plt.ylabel("Incidence Rate")
plt.show()

# %%
plt.plot(final_df["Median AQI"].astype("float"), final_df["Skin_IR"].astype("float"), "bo")
plt.title("Median AQI vs Skin Cancer Incidence Rate")
plt.xlabel("Median AQI")
plt.ylabel("Incidence Rate")
plt.show()

# %%
plt.plot(final_df["Days Ozone"].astype("float"), final_df["Lung_IR"].astype("float"), "bo")
plt.title("Days Ozone vs Leukemia Incidence Rate")
plt.xlabel("Days Ozone")
plt.ylabel("Incidence Rate")
plt.show()

# %%
# !!!!!!! Olga !!!!!!!

# %%
df_blood_mod = df_blood
df_blood_mod["Ilness_Type"] = "Blood cancer"
df_blood_mod["Ilness_Rate"] = df_blood_mod["Ilness_Rate"].str.replace("#", "")
df_blood_mod["Ilness_Rate"] = df_blood_mod["Ilness_Rate"].str.replace("*", "")
df_blood_mod["Ilness_Rate"] = df_blood_mod["Ilness_Rate"].str.replace("¶", "")
df_blood_mod.head()
# Out:
#                            County Ilness_Rate   Ilness_Type
# 1     Turner County, South Dakota        41.9  Blood cancer
# 2  Mountrail County, North Dakota        35.7  Blood cancer
# 3  Bon Homme County, South Dakota        32.6  Blood cancer
# 4          Iron County, Wisconsin        30.2  Blood cancer
# 5     Washington County, Kentucky        29.4  Blood cancer

# %%
df_lung_mod = df_lung
df_lung_mod["Ilness_Type"] = "Lung cancer"
df_lung_mod["Ilness_Rate"] = df_lung_mod["Ilness_Rate"].str.replace("#", "")
df_lung_mod["Ilness_Rate"] = df_lung_mod["Ilness_Rate"].str.replace("*", "")
df_lung_mod["Ilness_Rate"] = df_lung_mod["Ilness_Rate"].str.replace("¶", "")
df_lung_mod.head()
# Out:
#                         County Ilness_Rate  Ilness_Type
# 1        Union County, Florida       215.1  Lung cancer
# 2      Owsley County, Kentucky       179.7  Lung cancer
# 3    McCreary County, Kentucky       154.1  Lung cancer
# 4  North Slope Borough, Alaska       150.8  Lung cancer
# 5      Powell County, Kentucky       140.9  Lung cancer

# %%
df_skin_mod = df_skin
df_skin_mod["Ilness_Type"] = "Skin cancer"
df_skin_mod["Ilness_Rate"] = df_skin_mod["Ilness_Rate"].str.replace("#", "")
df_skin_mod["Ilness_Rate"] = df_skin_mod["Ilness_Rate"].str.replace("*", "")
df_skin_mod["Ilness_Rate"] = df_skin_mod["Ilness_Rate"].str.replace("¶", "")
df_skin_mod.head()
# Out:
#                     County Ilness_Rate  Ilness_Type
# 1      Beaver County, Utah        79.6  Skin cancer
# 2      Summit County, Utah        76.1  Skin cancer
# 3    Towns County, Georgia        62.1  Skin cancer
# 4  Pickens County, Georgia        61.6  Skin cancer
# 5  Lumpkin County, Georgia        56.8  Skin cancer

# %%
df_stroke_mod = df_stroke
df_stroke_mod["Ilness_Type"] = "Stroke"
df_stroke_mod.head()
# Out:
#                              County  Ilness_Rate Ilness_Type
# 0  Abbeville County, South Carolina         87.3      Stroke
# 1   Acadia Parish County, Louisiana         88.9      Stroke
# 2         Accomack County, Virginia         75.2      Stroke
# 3                 Ada County, Idaho         66.8      Stroke
# 4                Adair County, Iowa         62.0      Stroke

# %%
print("lung:")
print(df_lung_mod.count())
print("blood:")
print(df_blood_mod.count())
print("skin:")
print(df_skin_mod.count())
print("stroke:")
print(df_stroke_mod.count())
# Out:
# lung:
# County         2709
# Ilness_Rate    2709
# Ilness_Type    2709
# dtype: int64
# blood:
# County         3161
# Ilness_Rate    3141
# Ilness_Type    3169
# dtype: int64
# skin:
# County         2075
# Ilness_Rate    2075
# Ilness_Type    2075
# dtype: int64
# stroke:
# County         3222
# Ilness_Rate    3211
# Ilness_Type    3222
# dtype: int64

# %%
frames_cancer = [df_lung_mod, df_blood_mod, df_skin_mod, df_stroke_mod]
cancer_df = pd.concat(frames_cancer).reset_index()
cancer_df.count()
# Out:
# index          11175
# County         11167
# Ilness_Rate    11136
# Ilness_Type    11175
# dtype: int64

# %%
cancer_df.head()
# Out:
#    index                       County Ilness_Rate  Ilness_Type
# 0      1        Union County, Florida       215.1  Lung cancer
# 1      2      Owsley County, Kentucky       179.7  Lung cancer
# 2      3    McCreary County, Kentucky       154.1  Lung cancer
# 3      4  North Slope Borough, Alaska       150.8  Lung cancer
# 4      5      Powell County, Kentucky       140.9  Lung cancer

# %%
cancer_df[cancer_df["Ilness_Type"]=="Stroke"].count()
# Out:
# index          3222
# County         3222
# Ilness_Rate    3211
# Ilness_Type    3222
# dtype: int64

# %%
cancer_df[cancer_df["Ilness_Type"]=="Stroke"].iloc[0:10,:]
# Out:
#       index                            County Ilness_Rate Ilness_Type
# 7953      0  Abbeville County, South Carolina        87.3      Stroke
# 7954      1   Acadia Parish County, Louisiana        88.9      Stroke
# 7955      2         Accomack County, Virginia        75.2      Stroke
# 7956      3                 Ada County, Idaho        66.8      Stroke
# 7957      4                Adair County, Iowa          62      Stroke
# 7958      5            Adair County, Kentucky        84.2      Stroke
# 7959      6            Adair County, Missouri        80.1      Stroke
# 7960      7            Adair County, Oklahoma        76.8      Stroke
# 7961      8            Adams County, Colorado        67.3      Stroke
# 7962      9                Adams County, Iowa        74.7      Stroke

# %%
cancer_df[cancer_df["Ilness_Type"]=="Blood cancer"].iloc[0:10,:]
# Out:
#       index                          County Ilness_Rate   Ilness_Type
# 2709      1     Turner County, South Dakota        41.9  Blood cancer
# 2710      2  Mountrail County, North Dakota        35.7  Blood cancer
# 2711      3  Bon Homme County, South Dakota        32.6  Blood cancer
# 2712      4          Iron County, Wisconsin        30.2  Blood cancer
# 2713      5     Washington County, Kentucky        29.4  Blood cancer
# 2714      6           Ford County, Illinois        27.8  Blood cancer
# 2715      7          Scott County, Arkansas        27.5  Blood cancer
# 2716      8      Union County, South Dakota        27.4  Blood cancer
# 2717      9               Page County, Iowa        26.6  Blood cancer
# 2718     10         Barton County, Missouri        26.3  Blood cancer

# %%
# Clearing data
#cancer_df["Ilness_Rate"].loc[cancer_df["Ilness_Type" ]!= "Stroke"] = cancer_df["Ilness_Rate"].str.replace("#", "")
# cancer_df["Ilness_Rate"] = cancer_df["Ilness_Rate"].str.replace("#", "")
# cancer_df["Ilness_Rate"] = cancer_df["Ilness_Rate"].str.replace("*", "")
# cancer_df["Ilness_Rate"] = cancer_df["Ilness_Rate"].str.replace("¶", "")

# %%
cancer_df.reset_index()
cancer_df.set_index("index", inplace = True)
cancer_df.head()
# Out:
#                             County Ilness_Rate  Ilness_Type
# index
# 1            Union County, Florida       215.1  Lung cancer
# 2          Owsley County, Kentucky       179.7  Lung cancer
# 3        McCreary County, Kentucky       154.1  Lung cancer
# 4      North Slope Borough, Alaska       150.8  Lung cancer
# 5          Powell County, Kentucky       140.9  Lung cancer

# %%
cancer_df.tail()
# Out:
#                              County Ilness_Rate Ilness_Type
# index
# 3217           Yuma County, Arizona          57      Stroke
# 3218          Yuma County, Colorado          62      Stroke
# 3219           Zapata County, Texas        73.5      Stroke
# 3220           Zavala County, Texas        76.3      Stroke
# 3221   Ziebach County, South Dakota        51.9      Stroke

# %%
cancer_df = cancer_df[cancer_df['Ilness_Rate'].isna()==False]

# %%
cancer_df.tail()
# Out:
#                              County Ilness_Rate Ilness_Type
# index
# 3217           Yuma County, Arizona          57      Stroke
# 3218          Yuma County, Colorado          62      Stroke
# 3219           Zapata County, Texas        73.5      Stroke
# 3220           Zavala County, Texas        76.3      Stroke
# 3221   Ziebach County, South Dakota        51.9      Stroke

# %%
aqi_illness_df_mod = pd.DataFrame(pd.merge(final_df_air, cancer_df, how = "inner", on='County'))
aqi_illness_df_mod.head()
# Out:
#                              County  Days with AQI  Good Days  Moderate Days  \
# 0  Abbeville County, South Carolina          220.6      205.6           14.8
# 1  Abbeville County, South Carolina          220.6      205.6           14.8
# 2  Abbeville County, South Carolina          220.6      205.6           14.8
# 3  Abbeville County, South Carolina          220.6      205.6           14.8
# 4                 Ada County, Idaho          365.2      285.0           72.0
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                  0.2             0.0                  0.0
# 1                                  0.2             0.0                  0.0
# 2                                  0.2             0.0                  0.0
# 3                                  0.2             0.0                  0.0
# 4                                  6.4             1.6                  0.2
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0             0.0     92.4                 48.6        36.2      0.0
# 1             0.0     92.4                 48.6        36.2      0.0
# 2             0.0     92.4                 48.6        36.2      0.0
# 3             0.0     92.4                 48.6        36.2      0.0
# 4             0.0    166.2                 65.0        39.4      4.8
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Ilness_Rate  \
# 0       0.0       220.6       0.0         0.0        0.0        69.2
# 1       0.0       220.6       0.0         0.0        0.0        11.9
# 2       0.0       220.6       0.0         0.0        0.0        18.2
# 3       0.0       220.6       0.0         0.0        0.0        87.3
# 4      47.0       223.6       0.2        47.0       42.6        52.3
#
#     Ilness_Type
# 0   Lung cancer
# 1  Blood cancer
# 2   Skin cancer
# 3        Stroke
# 4   Lung cancer

# %%
aqi_illness_df_mod = aqi_illness_df_mod[aqi_illness_df_mod['Ilness_Rate'].isna()==False]

# %%
aqi_illness_df_mod[aqi_illness_df_mod['Ilness_Rate'] == ' '] = np.nan

# %%
aqi_illness_df_mod['Ilness_Rate'] = aqi_illness_df_mod['Ilness_Rate'].astype('float')

# %%
aqi_illness_df_mod['Ilness_Type'] = aqi_illness_df_mod["Ilness_Type"].astype('category')

# %%
aqi_illness_df_mod["Ilness_Type"].value_counts()
# Out:
# Stroke          1071
# Lung cancer      985
# Skin cancer      925
# Blood cancer     874
# Name: Ilness_Type, dtype: int64

# %%
cm = plt.get_cmap('viridis')
cmap = sns.cubehelix_palette(dark=1, light=.5, as_cmap=True)

#colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple"]
colors = ["windows blue", "red", "faded green", "purple"]
#cm = plt.cm.register_cmap("windows blue", "red", "faded green", "purple")

# %%
# Create subplot
sns.set_palette("husl")
sns.set(style="white")
#sns.palplot(sns.xkcd_palette(colors))
#snc.set_palette(colors)
#sns.set_style(style="dark")

# Load the example mpg dataset
mpg = sns.load_dataset("mpg")

# Plot illness rate vs. Median AQ
ax = sns.relplot(x="Ilness_Rate", y="Median AQI", hue="Ilness_Type", #size="Days with AQI", markers="o", #edgecolor = "black",
            alpha=.5, palette="Set1", #palette="muted",
            height=6, data=aqi_illness_df_mod)

# Set title
# fig.suptitle("Illness rate vs. Median AQt)", y=0.95, fontsize=12, fontweight='bold')
suptitle = ax.fig.suptitle("Illness Rate vs. Median AQI")
# ax.fig(figsize(10,16))

# Save scatter plot
ax.fig.savefig("Images/IllnessVsMedianAQI.png", bbox_inches="tight")

# %%
ax = sns.relplot(x="Ilness_Rate", y="Max AQI", hue="Ilness_Type", #size="Days with AQI", markers="o", #edgecolor = "black",
            alpha=.5, palette="Set1", #palette="muted",
            height=6, data=aqi_illness_df_mod)

# Set title
# fig.suptitle("Illness rate vs. Median AQt)", y=0.95, fontsize=12, fontweight='bold')
suptitle = ax.fig.suptitle("Illness Rate vs. Max AQI")
# ax.fig(figsize(10,16))

# Save scatter plot
ax.fig.savefig("Images/IllnessVsMaxAQI.png", bbox_inches="tight")

# %%
ax = sns.relplot(x="Ilness_Rate", y="Days Ozone", hue="Ilness_Type", #size="Days with AQI", markers="o", #edgecolor = "black",
            alpha=.5, palette="Set1", #palette="muted",
            height=6, data=aqi_illness_df_mod)

# Set title
# fig.suptitle("Illness rate vs. Median AQt)", y=0.95, fontsize=12, fontweight='bold')
suptitle = ax.fig.suptitle("Illness Rate vs. Days Ozone")
# ax.fig(figsize(10,16))

# Save scatter plot
ax.fig.savefig("Images/IllnessVsDaysOzone.png", bbox_inches="tight")

# %%
ax = sns.relplot(x="Ilness_Rate", y="Days CO", hue="Ilness_Type", #size="Days with AQI", markers="o", #edgecolor = "black",
            alpha=.5, palette="Set1", #palette="muted",
            height=6, data=aqi_illness_df_mod)

# Set title
# fig.suptitle("Illness rate vs. Median AQt)", y=0.95, fontsize=12, fontweight='bold')
suptitle = ax.fig.suptitle("Illness Rate vs. Days CO")
# ax.fig(figsize(10,16))

# Save scatter plot
ax.fig.savefig("Images/IllnessVsDaysCO.png", bbox_inches="tight")

# %%
ax = sns.relplot(x="Ilness_Rate", y="Days NO2", hue="Ilness_Type", #size="Days with AQI", markers="o", #edgecolor = "black",
            alpha=.5, palette="Set1", #palette="muted",
            height=6, data=aqi_illness_df_mod)

# Set title
# fig.suptitle("Illness rate vs. Median AQt)", y=0.95, fontsize=12, fontweight='bold')
suptitle = ax.fig.suptitle("Illness Rate vs. Days NO2")
# ax.fig(figsize(10,16))

# Save scatter plot
ax.fig.savefig("Images/IllnessVsDaysNO2.png", bbox_inches="tight")

# %%
ax = sns.relplot(x="Ilness_Rate", y="Days SO2", hue="Ilness_Type", #size="Days with AQI", markers="o", #edgecolor = "black",
            alpha=.5, palette="Set1", #palette="muted",
            height=6, data=aqi_illness_df_mod)

# Set title
# fig.suptitle("Illness rate vs. Median AQt)", y=0.95, fontsize=12, fontweight='bold')
suptitle = ax.fig.suptitle("Illness Rate vs. Days SO2")
# ax.fig(figsize(10,16))

# Save scatter plot
ax.fig.savefig("Images/IllnessVsDaysSO2.png", bbox_inches="tight")

# %%
#aqi_illness_df_.loc[aqi_illness_df["Ilness_Type"] == "nan"]

# %%
ax = sns.relplot(x="Ilness_Rate", y="Days PM2.5", hue="Ilness_Type", #size="Days with AQI", markers="o", #edgecolor = "black",
            alpha=.5, palette="Set1", #palette="muted",
            height=6, data=aqi_illness_df_mod)

# Set title
# fig.suptitle("Illness rate vs. Median AQt)", y=0.95, fontsize=12, fontweight='bold')
suptitle = ax.fig.suptitle("Illness Rate vs. Days PM2.5")
# ax.fig(figsize(10,16))

# Save scatter plot
ax.fig.savefig("Images/IllnessVsDaysPM2.png", bbox_inches="tight")

# %%
ax = sns.relplot(x="Ilness_Rate", y="Days PM10", hue="Ilness_Type", #size="Days with AQI", markers="o", #edgecolor = "black",
            alpha=.5, palette="Set1", #palette="muted",
            height=6, data=aqi_illness_df_mod)

# Set title
# fig.suptitle("Illness rate vs. Median AQt)", y=0.95, fontsize=12, fontweight='bold')
suptitle = ax.fig.suptitle("Illness Rate vs. Days PM10")
# ax.fig(figsize(10,16))

# Save scatter plot
ax.fig.savefig("Images/IllnessVsDaysPM10.png", bbox_inches="tight")
